# %%
print('hello world')

# this is some error in the code
# Out:
# hello world

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10, 100)
y = np.sqrt(x)

fig, ax = plt.subplots()

ax.plot(x, y)
